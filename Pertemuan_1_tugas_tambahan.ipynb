# %% [markdown]
# <a href="https://colab.research.google.com/github/ta887yh-lgtm/Pemerograman-Dasar/blob/main/Pertemuan_1_tugas_tambahan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Tiara Putri Az Zahra"
umur = "20 tahun"
jurusan = "Teknik Elektro"
program_studi = "Teknologi Rekayasa Pembangkit Energi"
semester = 3
nim = 4232501048
matakuliah = "Pemerograman Dasar"
status_lulus = "false"
jenis_kelamin = "perempuan"
agama = "islam"
hobi = "membaca dan shopping"
tempat_tanggal_lahir = "Malang, 26 Mei 2006"
alamat = "Perumahan Graha Mas Blok C7 No 12A, RT/RW 02/013"
asal_sekolah = "Man 1 Kota Batam"


print (nama)
print (umur)
print (jurusan)
print (program_studi)
print (semester)
print (nim)
print (matakuliah)
print (status_lulus)
print (jenis_kelamin)
print (agama)
print (hobi)
print (tempat_tanggal_lahir)
print (alamat)
print (asal_sekolah)
# Out:
# Tiara Putri Az Zahra
# 20 tahun
# Teknik Elektro
# Teknologi Rekayasa Pembangkit Energi
# 3
# 4232501048
# Pemerograman Dasar
# false
# perempuan
# islam
# membaca dan shopping
# Malang, 26 Mei 2006
# Perumahan Graha Mas Blok C7 No 12A, RT/RW 02/013
# Man 1 Kota Batam
